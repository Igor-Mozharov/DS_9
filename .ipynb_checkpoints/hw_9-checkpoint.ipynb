# %%
import numpy as np
from tensorflow import keras
from keras.datasets import fashion_mnist
from keras.models import Sequential
from keras.layers import Dense
from keras import losses, metrics, optimizers
from keras.utils import to_categorical
from keras.layers.regularization import dropout

# %%
num_classes = 10
num_features = 784

# %%
(x_train, y_train), (x_test, y_test) = fashion_mnist.load_data()
x_train, x_test = np.array(x_train, np.float32), np.array(x_test, np.float32)
x_train, x_test = np.reshape(x_train, (-1, num_features)), np.reshape(x_test, (-1, num_features))
x_train, x_test = x_train / 255., x_test / 255.
y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

# %%
model = Sequential()
model.add(Dense(1024, activation='relu', input_shape=(num_features, )))
model.add(Dense(512, activation='relu'))
model.add(Dense(num_classes, activation='softmax'))
model.compile(optimizer=optimizers.RMSprop(learning_rate=0.002),
              metrics=[metrics.accuracy],
              loss=losses.binary_crossentropy)

# %%
result = model.fit(x_train, y_train, batch_size=40, epochs=100, shuffle=False, validation_split=0.34)
# Out:
# Epoch 1/100
# 990/990 [==============================] - 4s 4ms/step - loss: 0.1038 - accuracy: 0.0333 - val_loss: 0.0782 - val_accuracy: 0.0721
# Epoch 2/100
# 990/990 [==============================] - 4s 4ms/step - loss: 0.0782 - accuracy: 0.1191 - val_loss: 0.0897 - val_accuracy: 0.1646
# Epoch 3/100
# 990/990 [==============================] - 4s 4ms/step - loss: 0.0735 - accuracy: 0.1736 - val_loss: 0.0870 - val_accuracy: 0.1946
# Epoch 4/100
# 990/990 [==============================] - 4s 4ms/step - loss: 0.0708 - accuracy: 0.2162 - val_loss: 0.0915 - val_accuracy: 0.2565
# Epoch 5/100
# 990/990 [==============================] - 4s 4ms/step - loss: 0.0686 - accuracy: 0.2624 - val_loss: 0.0949 - val_accuracy: 0.2862
# Epoch 6/100
# 990/990 [==============================] - 4s 4ms/step - loss: 0.0671 - accuracy: 0.2997 - val_loss: 0.0911 - val_accuracy: 0.3040
# Epoch 7/100
# ...
